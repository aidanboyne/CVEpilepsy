# %%
import os
import random
from sklearn.model_selection import StratifiedKFold
from collections import defaultdict, Counter

# %%
master_file = os.path.join(os.getcwd(), 'annotations', 'aidan_allclips_annotations.txt')
output_dir = os.path.join(os.getcwd(), 'annotations', 'Uncropped_LOPO_CV')

# %%
import os
import random
from collections import defaultdict
from sklearn.model_selection import train_test_split

def read_master_file(file_path):
    clips = []
    labels = []
    with open(file_path, 'r') as f:
        for line in f:
            clip, label = line.strip().split()
            clips.append(clip)
            labels.append(int(label))
    return clips, labels

def write_annotation_file(file_path, clips, labels):
    with open(file_path, 'w') as f:
        for clip, label in zip(clips, labels):
            f.write(f"{clip} {label}\n")

def balance_data(clips, labels):
    positive = [(c, l) for c, l in zip(clips, labels) if l == 1]
    negative = [(c, l) for c, l in zip(clips, labels) if l == 0]
    
    n_samples = min(len(positive), len(negative))
    balanced = random.sample(positive, n_samples) + random.sample(negative, n_samples)
    random.shuffle(balanced)
    return zip(*balanced)

def group_by_patient(clips, labels):
    patient_groups = defaultdict(lambda: {'clips': [], 'labels': []})
    for clip, label in zip(clips, labels):
        patient = clip.split('/')[1].split('_')[0]  # Extract patient number
        patient_groups[patient]['clips'].append(clip)
        patient_groups[patient]['labels'].append(label)
    return patient_groups

def create_cross_validation_files(master_file, output_dir):
    clips, labels = read_master_file(master_file)
    patient_groups = group_by_patient(clips, labels)

    patients = list(patient_groups.keys())
    random.shuffle(patients)

    for fold, test_patient in enumerate(patients):
        fold_dir = os.path.join(output_dir, f"fold_{fold+1}")
        os.makedirs(fold_dir, exist_ok=True)

        # Separate test patient
        test_clips = patient_groups[test_patient]['clips']
        test_labels = patient_groups[test_patient]['labels']

        # Collect clips and labels for train+val set
        train_val_clips, train_val_labels = [], []
        for patient in patients:
            if patient != test_patient:
                train_val_clips.extend(patient_groups[patient]['clips'])
                train_val_labels.extend(patient_groups[patient]['labels'])

        # Split train+val into train and val (80:20)
        train_clips, val_clips, train_labels, val_labels = train_test_split(
            train_val_clips, train_val_labels, test_size=0.2, stratify=train_val_labels, random_state=42
        )

        # Balance data for each set
        train_clips, train_labels = balance_data(train_clips, train_labels)
        val_clips, val_labels = balance_data(val_clips, val_labels)
        test_clips, test_labels = balance_data(test_clips, test_labels)

        # Write annotation files
        write_annotation_file(os.path.join(fold_dir, "train.txt"), train_clips, train_labels)
        write_annotation_file(os.path.join(fold_dir, "val.txt"), val_clips, val_labels)
        write_annotation_file(os.path.join(fold_dir, "test.txt"), test_clips, test_labels)

        print(f"Fold {fold+1}: Test patient {test_patient}")

# %%
create_cross_validation_files(master_file, output_dir)
# Out:
# Fold 1: Test patient 06338772
# Fold 2: Test patient 05454991
# Fold 3: Test patient 00582992
# Fold 4: Test patient 06452950
# Fold 5: Test patient 05447543
# Fold 6: Test patient 05497695
# Fold 7: Test patient 05467817
# Fold 8: Test patient 05418761
# Fold 9: Test patient 06348578
# Fold 10: Test patient 06381028
# Fold 11: Test patient 00913367
# Fold 12: Test patient 06394294
# Fold 13: Test patient 05512494
# Fold 14: Test patient 05235825
# Fold 15: Test patient 05323733
# Fold 16: Test patient 05514820
# Fold 17: Test patient 05463487
# Fold 18: Test patient 05513119
# Fold 19: Test patient 05486196
# Fold 20: Test patient 05109836
# Fold 21: Test patient 05352576
# Fold 22: Test patient 02268547
# Fold 23: Test patient 05501184
# Fold 24: Test patient 05489744
# Fold 25: Test patient 02267738

# %% [markdown]
# #### Ensure the files were created properly

# %%
def analyze_cross_validation(base_dir):
    for fold in range(1, 26):  # 4 folds
        fold_dir = os.path.join(base_dir, f"fold_{fold}")
        print(f"\nAnalyzing Fold {fold}:")
        
        set_counts = {}
        set_patients = {}
        set_labels = {}
        total_videos = 0
        
        for set_name in ['train', 'val', 'test']:
            file_path = os.path.join(fold_dir, f"{set_name}.txt")
            
            videos = []
            patients = set()
            labels = []
            
            with open(file_path, 'r') as f:
                for line in f:
                    video_path, label = line.strip().split()
                    videos.append(video_path)
                    labels.append(int(label))
                    patient = video_path.split('/')[1].split('_')[0]  # Extract patient number
                    patients.add(patient)
            
            set_counts[set_name] = len(videos)
            set_patients[set_name] = patients
            set_labels[set_name] = labels
            total_videos += len(videos)
        
        # Print counts, percentages, and label ratios
        print(f"Total videos in fold: {total_videos}")
        for set_name in ['train', 'val', 'test']:
            count = set_counts[set_name]
            percentage = (count / total_videos) * 100
            negative_count = set_labels[set_name].count(0)
            positive_count = set_labels[set_name].count(1)
            negative_ratio = (negative_count / count) * 100
            positive_ratio = (positive_count / count) * 100
            
            print(f"{set_name.capitalize()} set: {count} videos ({percentage:.2f}%)")
            print(f"  Negative (0) clips: {negative_count} ({negative_ratio:.2f}%)")
            print(f"  Positive (1) clips: {positive_count} ({positive_ratio:.2f}%)")
        
        # Print patients in each set
        for set_name in ['train', 'val', 'test']:
            print(f"\nPatients in {set_name} set: {', '.join(sorted(set_patients[set_name]))}")
        
        # Check for patient overlap
        all_patients = set()
        for patients in set_patients.values():
            all_patients.update(patients)
        
        patient_count = defaultdict(int)
        for patients in set_patients.values():
            for patient in patients:
                patient_count[patient] += 1
        
        # overlapping_patients = [patient for patient, count in patient_count.items() if count > 1]
        
        # if overlapping_patients:
        #     print("\nWARNING: The following patients appear in multiple sets:")
        #     for patient in overlapping_patients:
        #         print(f"Patient {patient} appears in:")
        #         for set_name, patients in set_patients.items():
        #             if patient in patients:
        #                 print(f"  - {set_name} set")
        # else:
        #     print("\nVerification successful: No patients appear in multiple sets within this fold.")

# %%
analyze_cross_validation(output_dir)
# Out:
# Analyzing Fold 1:
# Total videos in fold: 2132
# Train set: 1672 videos (78.42%)
#   Negative (0) clips: 836 (50.00%)
#   Positive (1) clips: 836 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 42 videos (1.97%)
#   Negative (0) clips: 21 (50.00%)
#   Positive (1) clips: 21 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 06338772
#
# Analyzing Fold 2:
# Total videos in fold: 2132
# Train set: 1672 videos (78.42%)
#   Negative (0) clips: 836 (50.00%)
#   Positive (1) clips: 836 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 42 videos (1.97%)
#   Negative (0) clips: 21 (50.00%)
#   Positive (1) clips: 21 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05454991
#
# Analyzing Fold 3:
# Total videos in fold: 2132
# Train set: 1600 videos (75.05%)
#   Negative (0) clips: 800 (50.00%)
#   Positive (1) clips: 800 (50.00%)
# Val set: 400 videos (18.76%)
#   Negative (0) clips: 200 (50.00%)
#   Positive (1) clips: 200 (50.00%)
# Test set: 132 videos (6.19%)
#   Negative (0) clips: 66 (50.00%)
#   Positive (1) clips: 66 (50.00%)
#
# Patients in train set: 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 00582992
#
# Analyzing Fold 4:
# Total videos in fold: 2132
# Train set: 1676 videos (78.61%)
#   Negative (0) clips: 838 (50.00%)
#   Positive (1) clips: 838 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 38 videos (1.78%)
#   Negative (0) clips: 19 (50.00%)
#   Positive (1) clips: 19 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294
#
# Patients in test set: 06452950
#
# Analyzing Fold 5:
# Total videos in fold: 2132
# Train set: 1594 videos (74.77%)
#   Negative (0) clips: 797 (50.00%)
#   Positive (1) clips: 797 (50.00%)
# Val set: 398 videos (18.67%)
#   Negative (0) clips: 199 (50.00%)
#   Positive (1) clips: 199 (50.00%)
# Test set: 140 videos (6.57%)
#   Negative (0) clips: 70 (50.00%)
#   Positive (1) clips: 70 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05447543
#
# Analyzing Fold 6:
# Total videos in fold: 2132
# Train set: 1562 videos (73.26%)
#   Negative (0) clips: 781 (50.00%)
#   Positive (1) clips: 781 (50.00%)
# Val set: 390 videos (18.29%)
#   Negative (0) clips: 195 (50.00%)
#   Positive (1) clips: 195 (50.00%)
# Test set: 180 videos (8.44%)
#   Negative (0) clips: 90 (50.00%)
#   Positive (1) clips: 90 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05497695
#
# Analyzing Fold 7:
# Total videos in fold: 2132
# Train set: 1666 videos (78.14%)
#   Negative (0) clips: 833 (50.00%)
#   Positive (1) clips: 833 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 50 videos (2.35%)
#   Negative (0) clips: 25 (50.00%)
#   Positive (1) clips: 25 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05467817
#
# Analyzing Fold 8:
# Total videos in fold: 2132
# Train set: 1656 videos (77.67%)
#   Negative (0) clips: 828 (50.00%)
#   Positive (1) clips: 828 (50.00%)
# Val set: 414 videos (19.42%)
#   Negative (0) clips: 207 (50.00%)
#   Positive (1) clips: 207 (50.00%)
# Test set: 62 videos (2.91%)
#   Negative (0) clips: 31 (50.00%)
#   Positive (1) clips: 31 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05418761
#
# Analyzing Fold 9:
# Total videos in fold: 2132
# Train set: 1614 videos (75.70%)
#   Negative (0) clips: 807 (50.00%)
#   Positive (1) clips: 807 (50.00%)
# Val set: 404 videos (18.95%)
#   Negative (0) clips: 202 (50.00%)
#   Positive (1) clips: 202 (50.00%)
# Test set: 114 videos (5.35%)
#   Negative (0) clips: 57 (50.00%)
#   Positive (1) clips: 57 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06381028, 06394294, 06452950
#
# Patients in test set: 06348578
#
# Analyzing Fold 10:
# Total videos in fold: 2132
# Train set: 1648 videos (77.30%)
#   Negative (0) clips: 824 (50.00%)
#   Positive (1) clips: 824 (50.00%)
# Val set: 412 videos (19.32%)
#   Negative (0) clips: 206 (50.00%)
#   Positive (1) clips: 206 (50.00%)
# Test set: 72 videos (3.38%)
#   Negative (0) clips: 36 (50.00%)
#   Positive (1) clips: 36 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06394294, 06452950
#
# Patients in test set: 06381028
#
# Analyzing Fold 11:
# Total videos in fold: 2132
# Train set: 1628 videos (76.36%)
#   Negative (0) clips: 814 (50.00%)
#   Positive (1) clips: 814 (50.00%)
# Val set: 406 videos (19.04%)
#   Negative (0) clips: 203 (50.00%)
#   Positive (1) clips: 203 (50.00%)
# Test set: 98 videos (4.60%)
#   Negative (0) clips: 49 (50.00%)
#   Positive (1) clips: 49 (50.00%)
#
# Patients in train set: 00582992, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 00913367
#
# Analyzing Fold 12:
# Total videos in fold: 2132
# Train set: 1580 videos (74.11%)
#   Negative (0) clips: 790 (50.00%)
#   Positive (1) clips: 790 (50.00%)
# Val set: 396 videos (18.57%)
#   Negative (0) clips: 198 (50.00%)
#   Positive (1) clips: 198 (50.00%)
# Test set: 156 videos (7.32%)
#   Negative (0) clips: 78 (50.00%)
#   Positive (1) clips: 78 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06452950
#
# Patients in test set: 06394294
#
# Analyzing Fold 13:
# Total videos in fold: 2132
# Train set: 1684 videos (78.99%)
#   Negative (0) clips: 842 (50.00%)
#   Positive (1) clips: 842 (50.00%)
# Val set: 422 videos (19.79%)
#   Negative (0) clips: 211 (50.00%)
#   Positive (1) clips: 211 (50.00%)
# Test set: 26 videos (1.22%)
#   Negative (0) clips: 13 (50.00%)
#   Positive (1) clips: 13 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05512494
#
# Analyzing Fold 14:
# Total videos in fold: 2132
# Train set: 1672 videos (78.42%)
#   Negative (0) clips: 836 (50.00%)
#   Positive (1) clips: 836 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 42 videos (1.97%)
#   Negative (0) clips: 21 (50.00%)
#   Positive (1) clips: 21 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05235825
#
# Analyzing Fold 15:
# Total videos in fold: 2132
# Train set: 1676 videos (78.61%)
#   Negative (0) clips: 838 (50.00%)
#   Positive (1) clips: 838 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 38 videos (1.78%)
#   Negative (0) clips: 19 (50.00%)
#   Positive (1) clips: 19 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05323733
#
# Analyzing Fold 16:
# Total videos in fold: 2132
# Train set: 1680 videos (78.80%)
#   Negative (0) clips: 840 (50.00%)
#   Positive (1) clips: 840 (50.00%)
# Val set: 420 videos (19.70%)
#   Negative (0) clips: 210 (50.00%)
#   Positive (1) clips: 210 (50.00%)
# Test set: 32 videos (1.50%)
#   Negative (0) clips: 16 (50.00%)
#   Positive (1) clips: 16 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05514820
#
# Analyzing Fold 17:
# Total videos in fold: 2132
# Train set: 1668 videos (78.24%)
#   Negative (0) clips: 834 (50.00%)
#   Positive (1) clips: 834 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 48 videos (2.25%)
#   Negative (0) clips: 24 (50.00%)
#   Positive (1) clips: 24 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05463487
#
# Analyzing Fold 18:
# Total videos in fold: 2132
# Train set: 1664 videos (78.05%)
#   Negative (0) clips: 832 (50.00%)
#   Positive (1) clips: 832 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 52 videos (2.44%)
#   Negative (0) clips: 26 (50.00%)
#   Positive (1) clips: 26 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05513119
#
# Analyzing Fold 19:
# Total videos in fold: 2132
# Train set: 1664 videos (78.05%)
#   Negative (0) clips: 832 (50.00%)
#   Positive (1) clips: 832 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 52 videos (2.44%)
#   Negative (0) clips: 26 (50.00%)
#   Positive (1) clips: 26 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05486196
#
# Analyzing Fold 20:
# Total videos in fold: 2132
# Train set: 1580 videos (74.11%)
#   Negative (0) clips: 790 (50.00%)
#   Positive (1) clips: 790 (50.00%)
# Val set: 394 videos (18.48%)
#   Negative (0) clips: 197 (50.00%)
#   Positive (1) clips: 197 (50.00%)
# Test set: 158 videos (7.41%)
#   Negative (0) clips: 79 (50.00%)
#   Positive (1) clips: 79 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05109836
#
# Analyzing Fold 21:
# Total videos in fold: 2132
# Train set: 1488 videos (69.79%)
#   Negative (0) clips: 744 (50.00%)
#   Positive (1) clips: 744 (50.00%)
# Val set: 372 videos (17.45%)
#   Negative (0) clips: 186 (50.00%)
#   Positive (1) clips: 186 (50.00%)
# Test set: 272 videos (12.76%)
#   Negative (0) clips: 136 (50.00%)
#   Positive (1) clips: 136 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05352576
#
# Analyzing Fold 22:
# Total videos in fold: 2132
# Train set: 1674 videos (78.52%)
#   Negative (0) clips: 837 (50.00%)
#   Positive (1) clips: 837 (50.00%)
# Val set: 418 videos (19.61%)
#   Negative (0) clips: 209 (50.00%)
#   Positive (1) clips: 209 (50.00%)
# Test set: 40 videos (1.88%)
#   Negative (0) clips: 20 (50.00%)
#   Positive (1) clips: 20 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 02268547
#
# Analyzing Fold 23:
# Total videos in fold: 2132
# Train set: 1664 videos (78.05%)
#   Negative (0) clips: 832 (50.00%)
#   Positive (1) clips: 832 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 52 videos (2.44%)
#   Negative (0) clips: 26 (50.00%)
#   Positive (1) clips: 26 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05501184
#
# Analyzing Fold 24:
# Total videos in fold: 2132
# Train set: 1588 videos (74.48%)
#   Negative (0) clips: 794 (50.00%)
#   Positive (1) clips: 794 (50.00%)
# Val set: 398 videos (18.67%)
#   Negative (0) clips: 199 (50.00%)
#   Positive (1) clips: 199 (50.00%)
# Test set: 146 videos (6.85%)
#   Negative (0) clips: 73 (50.00%)
#   Positive (1) clips: 73 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02267738, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 05489744
#
# Analyzing Fold 25:
# Total videos in fold: 2132
# Train set: 1668 videos (78.24%)
#   Negative (0) clips: 834 (50.00%)
#   Positive (1) clips: 834 (50.00%)
# Val set: 416 videos (19.51%)
#   Negative (0) clips: 208 (50.00%)
#   Positive (1) clips: 208 (50.00%)
# Test set: 48 videos (2.25%)
#   Negative (0) clips: 24 (50.00%)
#   Positive (1) clips: 24 (50.00%)
#
# Patients in train set: 00582992, 00913367, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in val set: 00582992, 00913367, 02268547, 05109836, 05235825, 05323733, 05352576, 05418761, 05447543, 05454991, 05463487, 05467817, 05486196, 05489744, 05497695, 05501184, 05512494, 05513119, 05514820, 06338772, 06348578, 06381028, 06394294, 06452950
#
# Patients in test set: 02267738
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Write individual video annotation files for testing

# %%
from collections import defaultdict

# Function to read the annotations file and group entries
def group_annotations(file_path):
    groups = defaultdict(list)
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.split()
            video_path = parts[0]
            label = parts[1]
            # Extract the XXXXXXXX identifier from the file name
            identifier = video_path.split('_')[2]
            groups[identifier].append(line.strip())
    return groups

# Function to write grouped entries to separate files
def write_grouped_annotations(groups, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    for identifier, lines in groups.items():
        output_file_path = os.path.join(output_dir, f'{identifier}.txt')
        with open(output_file_path, 'w+') as output_file:
            for line in lines:
                output_file.write(line + '\n')

# Main function
def write_test_annotations(input_file, output_dir):
    groups = group_annotations(input_file)
    write_grouped_annotations(groups, output_dir)
    print(f"Annotations have been successfully grouped and written to '{output_dir}'.")

# %%
input_file = os.path.join(os.getcwd(), "annotations", "aidan_allclips_annotations.txt")  # Path to the input annotations file
output_dir = os.path.join(os.getcwd(), "annotations", "video_test_annotations")  # Directory to store the grouped files
write_test_annotations(input_file, output_dir)
# Out:
# Annotations have been successfully grouped and written to 'c:\Users\u251245\CVEpilepsy_remote\annotations\video_test_annotations'.
